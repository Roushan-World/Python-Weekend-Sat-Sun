# %% [markdown]
# # 13. Classes and Objects in Python

# %% [markdown]
# # Create a class

# %%
class Data:
    num=3.14
    
    
print(Data)
# Out:
# <class '__main__.Data'>

# %%
class Data:
    num=3.14
    name='Amruta'
var=Data()
print(var.num)
print(var.name)
# Out:
# 3.14
# Amruta

# %% [markdown]
# # function init()

# %%
class Data:
    def __init__(self,name,age):
        self.name=name
        self.age=age
        
        
        
val=Data('Amruta','30')

print(val.name)
print(val.age)
# Out:
# Amruta
# 30

# %%
class Data:
    def __init__(self,name,age,contact):
        self.name=name
        self.age=age
        self.contact=contact
    def detail(self):
        print('My name is',self.name)
        print('My age is',self.age)
        print('You can contact me',self.contact)
val= Data('Bob',30,'bob@gamil.com')
val.detail()
# Out:
# My name is Bob
# My age is 30
# You can contact me bob@gamil.com

# %% [markdown]
# # Self parameter
#
#
#  * The self parameter is a reference to the current instance of the class, and is used to access variables that
#  belongs to the class.
#
#  * It does not have to be named self, you can call it whatever you like, but it has to be the first parameter of
#  any function in the class.

# %% [markdown]
# # Creating a Class to draw a Rectangle

# %%
# Creating a class to draw rectangle
class Rectangle(object):
    # Constructor
    
    def __init__(self,width,height,color):
        self.width=width
        self.height=height
        self.color=color
        
        
    # method
    def drawRectangle(self):
        plt.gca().add_patch(plt.Rectangle((0,0),self.width,self.height,fc=self.color))
        plt.axis('scaled')
        plt.show()
        
# import library to draw the Rectangle

import matplotlib.pyplot as plt
# %matplotlib inline

# creating an object blue rectangle

one_Rectangel=Rectangle(20,10,'blue')

# Printing the object attribute width

print(one_Rectangel.width)

# printing the obeject attribute height

print(one_Rectangel.height)

# printing the obeject attribte color

print(one_Rectangel.color)

#Drawing the object

one_Rectangel.drawRectangle()

# learning the met

print(dir(one_Rectangel))

one_Rectangel.width=15
one_Rectangel.height=15
one_Rectangel.color='green'
one_Rectangel.drawRectangle()

two_Rectangle=Rectangle(100,50,'yellow')
two_Rectangle.drawRectangle()
# Out:
# 20
# 10
# blue
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'color', 'drawRectangle', 'height', 'width']

# %%
three_Rectangle=Rectangle(150,100,'red')
three_Rectangle.drawRectangle()

# %%
fourth_Rectangle=Rectangle(150,100,'pink')
fourth_Rectangle.drawRectangle()

# %% [markdown]
# #  Creating a class to draw a circle

# %%
# Creating a class to draw a circle
class Circle(object):
    
    # Constructor
    
    def __init__ (self,radius,color):
        self.radius=radius
        self.color=color
        
    #method
    def increase_radius(self,r):
        self.radius=self.radius+r
        return self.radius
    
    # method
    
    def drawCircle(self):
        plt.gca().add_patch(plt.Circle((0,0),self.radius,fc=self.color))
        plt.axis('scaled')
        plt.show()
        
# import library to draw the circle
import matplotlib.pyplot as plt
# %matplotlib inline

# Creating an object blue circle
one_Circle=Circle(3.14,'blue')
print(one_Circle.radius)
print(one_Circle.color)
one_Circle.drawCircle()

print(dir(one_Circle))
# Out:
# 3.14
# blue
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'color', 'drawCircle', 'increase_radius', 'radius']

# %%
one_Circle.radius=15
one_Circle.color='green'
one_Circle.drawCircle()

# %%
class Parents:
    def __init__(self,genus,species):
        
        self.genus=genus
        self.species=species
    
    def microorganism(self):
        print(f'The name of microorganism is in the form of {self.genus} {self.species}.')
        
        
class child(Parents):
    pass

value=boy('alpha-2-macroglobulin','Homo habilis')
value.microorganism()
# Out:
# The name of microorganism is in the form of alpha-2-macroglobulin Homo habilis.

# %%
class ComplexNum:
    def __init__(self,a,b):
        self.a=a
        self.b=b
        
    def data(self):
        print(f'{self.a} {self.b}')
        
class child(ComplexNum):
    pass
var=child(3.14,1.618)
print(var.a,var.b)
# Out:
# 3.14 1.618

# %%
class person:
    
    def __init__(self,firstname,lastname):
        self.firstname=firstname
        self.lastname=lastname
    def printname(self):
        print(self.firstname,self.lastname)
        
        
x=person('John','Barbie')

x.printname()
# Out:
# John Barbie

# %%
class Data:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def status(self):
        return True
    def Programming(self):
        return True
    
class Data_Scientist(Data):
    pass

dt_sci=Data_Scientist('Marry',25)
print('Name:',dt_sci.name)
print('Age:',dt_sci.age)
# Out:
# Name: Marry
# Age: 25

# %% [markdown]
# * Simple(Single) Inheritance------------Parent Class and Child Class
#
# * Multi Level Inheritance-------------- Parent class--Parentclass/child class---Child class
#
# * Multiple Inheritance----------------- Parent class and Parent Class---------- Child class
#
# * Hierarchical Inheritance------------- Parent------------ Child Class------- Child class

# %%
# Single Inheritance
class parent:
    def func1(self):
        print('This function is parent class.')
        
class Child(parent):
    def func2(self):
        print(' This function is in child class.')
        
object= Child()
object.func2()
object.func1()
# Out:
#  This function is in child class.
# This function is parent class.

# %%
# Multiple Inheritance
# Base class1
class Mother:
    mothername=""
    def mother(self):
        print(self.mothername)
# Base class2
class Father:
    fathername=''
    def father(self):
        print(self.fathername)
        
# Derived class

class Son(Mother,Father):
    def parents(self):
        print('Father:',self.fathername)
        print('Mother:',self.mothername)
        
s1=Son()
s1.mothername='SITA'
s1.fathername='RAM'
s1.parents()
# Out:
# Father: RAM
# Mother: SITA

# %%
# Multilevel Inheritance

class Grandfather:
    def __init__(self,grandfathername):
        self.grandfathername=grandfathername
        
# Intermediate class
class Father(Grandfather):
    def __init__(self,fathername,grandfathername):
        self.fathername=fathername
        # involving constructor of Grandfather class
        Grandfather.__init__(self,grandfathername)
        
        
class Son(Father):
    def __init__ (self,sonname,fathername,grandfathername):
        self.sonname=sonname
        
        # involving constructor of Father class
        Father.__init__(self,fathername,grandfathername)
        
    def print_name(self):
        print('Grandfather name:',self.grandfathername)
        print('Father_name:',self.fathername)
        print('Son_name:',self.sonname)
        
s1=Son('Bob','Prince','RajVeer')


s1.print_name()
# Out:
# Grandfather name: RajVeer
# Father_name: Prince
# Son_name: Bob
